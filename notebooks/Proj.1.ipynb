# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cfile=pd.read_csv("../data/raw/Customer_DF.csv")

# %%
display(cfile.head())
# Out:
#    Unnamed: 0              customerEmail       customerPhone  \
# 0           0     josephhoward@yahoo.com        400-108-5415
# 1           1     evansjeffery@yahoo.com      1-788-091-7546
# 2           2  andersonwilliam@yahoo.com        024.420.0375
# 3           3      rubenjuarez@yahoo.com  670.664.8168x94985
# 4           4           uchen@malone.com      1-981-877-0870
#
#          customerDevice                        customerIPAddress  \
# 0  yyeiaxpltf82440jnb3v                             8.129.104.40
# 1  r0jpm7xaeqqa3kr6mzum                          219.173.211.202
# 2  4m7h5ipl1shyavt6vv2r  67b7:3db8:67e0:3bea:b9d0:90c1:2b60:b9f0
# 3  slovx60t0i558may4ks0  95de:8565:5a66:792c:26e0:6cfb:7d87:11af
# 4  j0pd24k5h8dl2fqu0cz4                           196.89.235.192
#
#                               customerBillingAddress  No_Transactions  \
# 0            5493 Jones Islands\nBrownside, CA 51896                2
# ...

# %%
display(cfile.tail())
# Out:
#      Unnamed: 0                    customerEmail        customerPhone  \
# 163         163  mitchellvickie@brewer-jones.com    313-124-3836x3528
# 164         164                sbrown@hughes.biz  (250)632-6631x02499
# 165         165             johnlowery@gmail.com     635.676.0955x524
# 166         166    ethompson@jackson-sanders.com         962.300.2250
# 167         167          dawn05@tucker-brown.com   (089)703-7360x8848
#
#            customerDevice                       customerIPAddress  \
# 163  ecu7ezz0ue67v3fce1o3                          181.90.104.120
# 164  xgv918sclaz40qlp2fee                              16.166.2.0
# 165  969zz9zdj8z4gns4sx5p  f82c:811f:8a02:e2d6:79b:fcaa:42de:570b
# 166  navessqcnmc9csfjn5cj                         203.246.172.244
# 167  lu4fgcug8dr0dwbcuui1                           132.132.95.33
#
#                                 customerBillingAddress  No_Transactions  \
# ...

# %%
#import scipy.stats as st
#display(pd.crosstab(cfile['Fraud'],cfile['customerPhone'].apply(lambda value: "Yes" if ("x" in value)  else "No")))
#st.chi2_contingency(pd.crosstab(cfile['Fraud'],cfile['customerPhone'].apply(lambda value: "Yes" if ("x" in value)  else "No")))

# %%
tfile=pd.read_csv("../data/raw/cust_transaction_details.csv")

# %%
display(tfile.head())
# Out:
#    Unnamed: 0           customerEmail transactionId orderId paymentMethodId  \
# 0           0  josephhoward@yahoo.com      a9lcj51r  vjbdvd       wt07xm68b
# 1           1  josephhoward@yahoo.com      y4wcv03i  yp6x27       wt07xm68b
# 2           2  evansjeffery@yahoo.com      5mi94sfw  nlghpa       41ug157xz
# 3           3  evansjeffery@yahoo.com      br8ba1nu  uw0eeb       41ug157xz
# 4           4  evansjeffery@yahoo.com      a33145ss  bn44oh       y3xp697jx
#
#    paymentMethodRegistrationFailure paymentMethodType paymentMethodProvider  \
# 0                                 1              card          JCB 16 digit
# 1                                 1              card          JCB 16 digit
# 2                                 0           bitcoin      American Express
# 3                                 0           bitcoin      American Express
# 4                                 1           bitcoin         VISA 16 digit
#
#    transactionAmount  transactionFailed orderState
# ...

# %%
cfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              168 non-null    int64
#  1   customerEmail           168 non-null    object
#  2   customerPhone           168 non-null    object
#  3   customerDevice          168 non-null    object
#  4   customerIPAddress       168 non-null    object
#  5   customerBillingAddress  168 non-null    object
#  6   No_Transactions         168 non-null    int64
#  7   No_Orders               168 non-null    int64
#  8   No_Payments             168 non-null    int64
#  9   Fraud                   168 non-null    bool
# dtypes: bool(1), int64(4), object(5)
# memory usage: 12.1+ KB

# %%
# Changing the column names with '_' between names and lowercase the names

# %%
dfc = cfile.rename(columns={'customerEmail':'customer_email','customerPhone':'customer_phone','customerDevice':'customer_device', 
                              'customerIPAddress':'customer_ip_address','customerBillingAddress':'customer_billing_address',
                             'Fraud':'fraud','No_Transactions':'no_transactions','No_Orders':'no_orders',
                             'No_Payments':'no_payments'})

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                168 non-null    int64
#  1   customer_email            168 non-null    object
#  2   customer_phone            168 non-null    object
#  3   customer_device           168 non-null    object
#  4   customer_ip_address       168 non-null    object
#  5   customer_billing_address  168 non-null    object
#  6   no_transactions           168 non-null    int64
#  7   no_orders                 168 non-null    int64
#  8   no_payments               168 non-null    int64
#  9   fraud                     168 non-null    bool
# dtypes: bool(1), int64(4), object(5)
# memory usage: 12.1+ KB

# %%
dft = tfile.rename(columns={'customerEmail': 'customer_email','transactionId': 'transaction_id','orderId': 'order_id', 
                              'paymentMethodId': 'payment_method_id', 'paymentMethodRegistrationFailure': 'payment_method_registration_failure',
                          'paymentMethodType': 'payment_method_type', 'paymentMethodProvider': 'payment_method_provider', 'transactionAmount': 'transaction_amount',
                             'transactionFailed': 'transaction_failed','orderState': 'order_state' })

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 623 entries, 0 to 622
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0                           623 non-null    int64
#  1   customer_email                       623 non-null    object
#  2   transaction_id                       623 non-null    object
#  3   order_id                             623 non-null    object
#  4   payment_method_id                    623 non-null    object
#  5   payment_method_registration_failure  623 non-null    int64
#  6   payment_method_type                  623 non-null    object
#  7   payment_method_provider              623 non-null    object
#  8   transaction_amount                   623 non-null    int64
#  9   transaction_failed                   623 non-null    int64
#  10  order_state                          623 non-null    object
# ...

# %%
dft.to_csv(r'C:\Users\pbevi\Documents\Week_5\Midproject-Ecommerce_fraud\dft.csv')

# %%
zero_orders = dfc[dfc['no_orders'] == 0]
display(zero_orders)
zero_orders.shape
# Out:
#      Unnamed: 0                  customer_email        customer_phone  \
# 9             9      ubranch@rivera-parker.info    (772)964-8162x6310
# 23           23       guerramichael@hotmail.com          299-883-0904
# 34           34            zbennett@frazier.com      995.449.5115x498
# 38           38                 xwang@white.com      592.309.4963x427
# 40           40            johnlowery@gmail.com      737-377-9701x577
# 41           41  smithtiffany@davis-perkins.com    384.291.0196x66623
# 43           43              knichols@gmail.com    (664)946-1521x6991
# 44           44                gsimpson@cox.org      +23(4)1428642270
# 47           47       johnsonjennifer@yahoo.com  1-670-969-5075x27186
# 51           51               whodges@yahoo.com      791-857-3838x784
# 54           54               zthomas@gmail.com    731.957.1783x62296
# 67           67             dana23@lawrence.net      +78(3)5889318722
# ...

# %%
zero_transactions = dfc[dfc['no_transactions'] == 0]
display(zero_transactions)
zero_transactions.shape
# Out:
#      Unnamed: 0                  customer_email        customer_phone  \
# 9             9      ubranch@rivera-parker.info    (772)964-8162x6310
# 23           23       guerramichael@hotmail.com          299-883-0904
# 34           34            zbennett@frazier.com      995.449.5115x498
# 38           38                 xwang@white.com      592.309.4963x427
# 40           40            johnlowery@gmail.com      737-377-9701x577
# 41           41  smithtiffany@davis-perkins.com    384.291.0196x66623
# 43           43              knichols@gmail.com    (664)946-1521x6991
# 44           44                gsimpson@cox.org      +23(4)1428642270
# 47           47       johnsonjennifer@yahoo.com  1-670-969-5075x27186
# 51           51               whodges@yahoo.com      791-857-3838x784
# 54           54               zthomas@gmail.com    731.957.1783x62296
# 67           67             dana23@lawrence.net      +78(3)5889318722
# ...

# %%
#Selecting only transactions above 0 (same case for orders)
dfc2 = dfc.loc[dfc["no_transactions"] != 0]
display (dfc2)
# Out:
#      Unnamed: 0                   customer_email       customer_phone  \
# 0             0           josephhoward@yahoo.com         400-108-5415
# 1             1           evansjeffery@yahoo.com       1-788-091-7546
# 2             2        andersonwilliam@yahoo.com         024.420.0375
# 3             3            rubenjuarez@yahoo.com   670.664.8168x94985
# 4             4                 uchen@malone.com       1-981-877-0870
# ..          ...                              ...                  ...
# 163         163  mitchellvickie@brewer-jones.com    313-124-3836x3528
# 164         164                sbrown@hughes.biz  (250)632-6631x02499
# 165         165             johnlowery@gmail.com     635.676.0955x524
# 166         166    ethompson@jackson-sanders.com         962.300.2250
# 167         167          dawn05@tucker-brown.com   (089)703-7360x8848
#
#           customer_device                      customer_ip_address  \
# ...

# %%
#Checking if there are null values

# %%
dfc2.isnull().sum()
# Out:
# Unnamed: 0                  0
# customer_email              0
# customer_phone              0
# customer_device             0
# customer_ip_address         0
# customer_billing_address    0
# no_transactions             0
# no_orders                   0
# no_payments                 0
# fraud                       0
# dtype: int64

# %%
dft.isnull().sum()
# Out:
# Unnamed: 0                             0
# customer_email                         0
# transaction_id                         0
# order_id                               0
# payment_method_id                      0
# payment_method_registration_failure    0
# payment_method_type                    0
# payment_method_provider                0
# transaction_amount                     0
# transaction_failed                     0
# order_state                            0
# dtype: int64

# %%
# Describing the values

# %%
dfc2.describe()
# Out:
#        Unnamed: 0  no_transactions   no_orders  no_payments
# count  141.000000       141.000000  141.000000   141.000000
# mean    83.836879         4.418440    3.390071     2.297872
# std     49.762525         2.490427    1.680872     2.190058
# min      0.000000         1.000000    1.000000     1.000000
# 25%     39.000000         2.000000    2.000000     1.000000
# 50%     85.000000         4.000000    3.000000     2.000000
# 75%    126.000000         6.000000    4.000000     3.000000
# max    167.000000        15.000000    8.000000    15.000000

# %%
dft.describe()
# Out:
#        Unnamed: 0  payment_method_registration_failure  transaction_amount  \
# count  623.000000                           623.000000          623.000000
# mean   311.000000                             0.131621           34.598716
# std    179.988889                             0.338350           20.360247
# min      0.000000                             0.000000           10.000000
# 25%    155.500000                             0.000000           21.000000
# 50%    311.000000                             0.000000           34.000000
# 75%    466.500000                             0.000000           45.000000
# max    622.000000                             1.000000          353.000000
#
#        transaction_failed
# count          623.000000
# mean             0.269663
# std              0.444141
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              1.000000
# max              1.000000

# %%
# Checking if the data is really cleaned

# %%
print(dfc2['fraud'].unique())
# Out:
# [False  True]

# %%
print(dft['payment_method_type'].unique())
# Out:
# ['card' 'bitcoin' 'apple pay' 'paypal']

# %%
print(dft['payment_method_provider'].unique())
# Out:
# ['JCB 16 digit' 'American Express' 'VISA 16 digit' 'Discover' 'Voyager'
#  'VISA 13 digit' 'Maestro' 'Mastercard' 'Diners Club / Carte Blanche'
#  'JCB 15 digit']

# %%
print(dft['order_state'].unique())
# Out:
# ['pending' 'fulfilled' 'failed']

# %%
#Shape

# %%
dfc2.shape
# Out:
# (141, 10)

# %%
dft.shape
# Out:
# (623, 11)

# %%
#Frequency of fraud

# %%
dfc2['fraud'].value_counts()
# Out:
# False    87
# True     54
# Name: fraud, dtype: int64

# %%
display(dfc2)
# Out:
#      Unnamed: 0                   customer_email       customer_phone  \
# 0             0           josephhoward@yahoo.com         400-108-5415
# 1             1           evansjeffery@yahoo.com       1-788-091-7546
# 2             2        andersonwilliam@yahoo.com         024.420.0375
# 3             3            rubenjuarez@yahoo.com   670.664.8168x94985
# 4             4                 uchen@malone.com       1-981-877-0870
# ..          ...                              ...                  ...
# 163         163  mitchellvickie@brewer-jones.com    313-124-3836x3528
# 164         164                sbrown@hughes.biz  (250)632-6631x02499
# 165         165             johnlowery@gmail.com     635.676.0955x524
# 166         166    ethompson@jackson-sanders.com         962.300.2250
# 167         167          dawn05@tucker-brown.com   (089)703-7360x8848
#
#           customer_device                      customer_ip_address  \
# ...

# %%
#
states_ab = [ 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']

states_f = {
    'AK': 'Alaska',
    'AL': 'Alabama',
    'AR': 'Arkansas',
    'AZ': 'Arizona',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DC': 'District of Columbia',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'IA': 'Iowa',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'MA': 'Massachusetts',
    'MD': 'Maryland',
    'ME': 'Maine',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MO': 'Missouri',
    'MS': 'Mississippi',
    'MT': 'Montana',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'NE': 'Nebraska',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NV': 'Nevada',
    'NY': 'New York',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VA': 'Virginia',
    'VT': 'Vermont',
    'WA': 'Washington',
    'WI': 'Wisconsin',
    'WV': 'West Virginia',
    'WY': 'Wyoming'}

# %%
"AL" in states_f.keys()
# Out:
# True

# %%
#Writing a function to find the states
def get_state(x, states_f):
    state = x.split(",")[-1].replace(" ","")[:2]
    if (state in states_f.keys()):
        return states_f[state]
    else:
        return "Other"

# %%
get_state("5493 Jones Islands\nBrownside, JA 51896", states_f)
# Out:
# 'Other'

# %%
dfc2['state']=list(map(get_state,dfc2['customer_billing_address'],[states_f]*len(dfc2)))
dfc2.head()
# Out:
# C:\Users\pbevi\AppData\Local\Temp\ipykernel_21568\2980665878.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc2['state']=list(map(get_state,dfc2['customer_billing_address'],[states_f]*len(dfc2)))
#    Unnamed: 0             customer_email      customer_phone  \
# 0           0     josephhoward@yahoo.com        400-108-5415
# 1           1     evansjeffery@yahoo.com      1-788-091-7546
# 2           2  andersonwilliam@yahoo.com        024.420.0375
# 3           3      rubenjuarez@yahoo.com  670.664.8168x94985
# 4           4           uchen@malone.com      1-981-877-0870
#
#         customer_device                      customer_ip_address  \
# 0  yyeiaxpltf82440jnb3v                             8.129.104.40
# ...

# %%
dfc2.to_csv(r'C:\Users\pbevi\Documents\Week_5\Midproject-Ecommerce_fraud\dfc2_states.csv')

# %%
# customer file

# %%
sns.countplot(x=dfc2.no_transactions).set(title='nº transactions')
plt.savefig('transactions_t.png')

# %%
sns.countplot(x=dfc2.no_orders).set(title='nº orders')
plt.savefig('totalorder.png')

# %%
sns.countplot(x=dfc2.no_payments).set(title='nº payments')
plt.savefig('totalpay.png')

# %%
pd.crosstab(dfc2.no_transactions, dfc.fraud)
# Out:
# fraud            False  True
# no_transactions
# 1                   11      7
# 2                   12      6
# 3                    9      7
# 4                   12      7
# 5                   22      7
# 6                   12      7
# 7                    5      6
# 8                    3      2
# 10                   0      3
# 11                   0      1
# 13                   0      1
# 15                   1      0

# %%
sns.countplot(dfc2, x="no_transactions", hue="fraud").set_title('Fraud by transactions')
plt.savefig('total_transactions.png')

# %%
sns.countplot(dfc2, x="no_orders", hue="fraud").set_title('Fraud by orders')
plt.savefig('fraud_total.png')

# %%
# transactions graphs

# %%
sns.countplot(x=dft.payment_method_type).set(title='payment type')
plt.savefig('type_total.png')

# %%
ax = dft['payment_method_provider'].value_counts().sort_index(ascending=False).plot(kind='barh',
                                    figsize=(8,5),
                                    title="Frequency Payment provider")
ax.set_xlabel("Frequency")
ax.set_ylabel("Providers")

plt.savefig('totasl_.png')

# %%
ax = dft['order_state'].value_counts().plot(kind='bar',
                                    figsize=(8,5),
                                    title="Total Order State")

# %%
pd.crosstab(dft.payment_method_type, dft.order_state)
# Out:
# order_state          failed  fulfilled  pending
# payment_method_type
# apple pay                 4         41        4
# bitcoin                   6         40        1
# card                     48        397       34
# paypal                    5         38        5

# %%
pd.crosstab(dft.payment_method_provider, dft.order_state)
# Out:
# order_state                  failed  fulfilled  pending
# payment_method_provider
# American Express                  6         36        3
# Diners Club / Carte Blanche       5         43       10
# Discover                          2         34        5
# JCB 15 digit                      2         38        5
# JCB 16 digit                     15         97        6
# Maestro                           5         59        5
# Mastercard                        3         28        1
# VISA 13 digit                     1         54        3
# VISA 16 digit                    18         73        5
# Voyager                           6         54        1

# %%
sns.boxplot(data=dft, x="order_state", y="transaction_amount")
plt.savefig('total_stateorders.png')

# %%
sns.displot(data=dft, x="transaction_amount",hue="transaction_failed")
plt.savefig('total_transaction.png')

# %%
fraud_ip = dfc[dfc['fraud'] == True]
display(fraud_ip)
# Out:
#      Unnamed: 0                   customer_email       customer_phone  \
# 1             1           evansjeffery@yahoo.com       1-788-091-7546
# 4             4                 uchen@malone.com       1-981-877-0870
# 5             5         robinsoncynthia@dunn.com     +65(5)8997489788
# 6             6     samuel15@saunders-rhodes.com          05045239487
# 7             7             johnlowery@gmail.com         044-642-9860
# ..          ...                              ...                  ...
# 161         161       andre74@patrick-decker.com         150-073-8610
# 163         163  mitchellvickie@brewer-jones.com    313-124-3836x3528
# 164         164                sbrown@hughes.biz  (250)632-6631x02499
# 165         165             johnlowery@gmail.com     635.676.0955x524
# 166         166    ethompson@jackson-sanders.com         962.300.2250
#
#           customer_device                     customer_ip_address  \
# ...

# %%
#customer email with fraud in customer df
fraude=fraud_ip['customer_email'].unique()
fraude
# Out:
# array(['evansjeffery@yahoo.com', 'uchen@malone.com',
#        'robinsoncynthia@dunn.com', 'samuel15@saunders-rhodes.com',
#        'johnlowery@gmail.com', 'ubranch@rivera-parker.info',
#        'bowenwilliam@yahoo.com', 'gonzalesjackson@gmail.com',
#        'guerramichael@hotmail.com', 'catherine64@gmail.com',
#        '9es7t@u6n7x', 'jamescampbell@randall-pacheco.biz',
#        'kristina41@gmail.com', 'uguzman@yahoo.com',
#        'feliciabrown@gmail.com', 'joserowland@jones.com',
#        'hj8maoy@1jcfcxs7', 'suzanne21@gmail.com', 'cathy42@gibson.com',
#        'nancymayo@brown.com', 'warrenedward@arnold.com',
#        'michael57@oconnor.com', 'jonathan99@stafford.org',
#        'lleonard@turner-fleming.com', 'whitedavid@jones-lloyd.org',
#        'shelby24@hotmail.com', 'brittanydean@hotmail.com',
#        'craig83@rasmussen-alvarado.com', 'ukline@spears.biz',
#        'vmiller@hotmail.com', 'david45@gmail.com',
#        'fdavis@wolfe-brown.com', 'mtrevino@gutierrez.net',
# ...

# %%
# filter for fraud emails
dft_filtered = dft[dft['customer_email'].isin(['evansjeffery@yahoo.com', 'uchen@malone.com',
       'robinsoncynthia@dunn.com', 'samuel15@saunders-rhodes.com',
       'johnlowery@gmail.com', 'ubranch@rivera-parker.info',
       'bowenwilliam@yahoo.com', 'gonzalesjackson@gmail.com',
       'guerramichael@hotmail.com', 'catherine64@gmail.com',
       '9es7t@u6n7x', 'jamescampbell@randall-pacheco.biz',
       'kristina41@gmail.com', 'uguzman@yahoo.com',
       'feliciabrown@gmail.com', 'joserowland@jones.com',
       'hj8maoy@1jcfcxs7', 'suzanne21@gmail.com', 'cathy42@gibson.com',
       'nancymayo@brown.com', 'warrenedward@arnold.com',
       'michael57@oconnor.com', 'jonathan99@stafford.org',
       'lleonard@turner-fleming.com', 'whitedavid@jones-lloyd.org',
       'shelby24@hotmail.com', 'brittanydean@hotmail.com',
       'craig83@rasmussen-alvarado.com', 'ukline@spears.biz',
       'vmiller@hotmail.com', 'david45@gmail.com',
       'fdavis@wolfe-brown.com', 'mtrevino@gutierrez.net',
       'tmcpherson@wright.com', 'wdelacruz@yahoo.com',
       'brooksdustin@knight.info', '3fooiar@6eph', 'ugood@mosley.info',
       'marywalker@gmail.com', 'amywright@wallace-johnson.com',
       'iray@rogers.com', 'ctaylor@yahoo.com', 'koneal@henderson.biz',
       'oaguirre@hotmail.com', 'aliciaanthony@martin.com',
       'christinemills@mcgee.com', 'gwilcox@hotmail.com', '1yf0@jedyz63t',
       'kwalsh@lopez-gomez.biz', 'deborah38@yahoo.com',
       'andre74@patrick-decker.com', 'mitchellvickie@brewer-jones.com',
       'sbrown@hughes.biz', 'ethompson@jackson-sanders.com'])]
display(dft_filtered)
# Out:
#      Unnamed: 0                 customer_email transaction_id order_id  \
# 2             2         evansjeffery@yahoo.com       5mi94sfw   nlghpa
# 3             3         evansjeffery@yahoo.com       br8ba1nu   uw0eeb
# 4             4         evansjeffery@yahoo.com       a33145ss   bn44oh
# 13           13               uchen@malone.com       q8j3dgni   56h7iw
# 14           14               uchen@malone.com       xjulqy8x   kowj1v
# ..          ...                            ...            ...      ...
# 611         611  ethompson@jackson-sanders.com       piabwn96   cbxamb
# 612         612  ethompson@jackson-sanders.com       yneqvvwj   cbxamb
# 613         613  ethompson@jackson-sanders.com       l2t3xn9z   wjq6ep
# 614         614  ethompson@jackson-sanders.com       yb9ejssg   zynstd
# 615         615  ethompson@jackson-sanders.com       j3xzwavj   diw3zx
#
#     payment_method_id  payment_method_registration_failure  \
# ...

# %%
dft_filtered.to_csv(r'C:\Users\pbevi\Documents\Week_5\Midproject-Ecommerce_fraud\dft_filtered.csv')

# %%
fraud_ip[fraud_ip['customer_email'].duplicated() == True]
# Out:
#      Unnamed: 0        customer_email      customer_phone  \
# 40           40  johnlowery@gmail.com    737-377-9701x577
# 45           45  johnlowery@gmail.com    +16(4)9016414340
# 65           65  johnlowery@gmail.com         04712252182
# 79           79  johnlowery@gmail.com  1-820-539-4726x993
# 133         133  johnlowery@gmail.com      1-143-059-1833
# 155         155  johnlowery@gmail.com  076-099-0630x72770
# 165         165  johnlowery@gmail.com    635.676.0955x524
#
#           customer_device                      customer_ip_address  \
# 40   jz66ap43id2y35ivfqa5  6c21:ac1d:2089:68fa:abb7:8c00:525f:6588
# 45   cdx178qymd6vy77nm4x3                           222.79.159.140
# 65   311kdz4c1210iixltk2j   42b3:df19:86fe:abd9:dafe:f6c1:eb76:c72
# 79   2in0fh7lep289n8dcbdz                           163.128.139.42
# 133  tyijaify2hqadwslejyr   e4c:fb48:8ee2:9819:6ae8:8d3f:3b6a:a788
# 155  6qy6oa3nqutsyyxzc54c  f259:657f:f329:2fca:c06c:8b57:d6ac:2380
# ...

# %%
dtotal = pd.concat([dfc2, dft], axis=1)
display(dtotal)
# Out:
# C:\Users\pbevi\Documents\Week_5\Mid_bootcamp_project\venv\lib\site-packages\IPython\lib\pretty.py:778: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# C:\Users\pbevi\Documents\Week_5\Mid_bootcamp_project\venv\lib\site-packages\IPython\core\formatters.py:342: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#      Unnamed: 0             customer_email      customer_phone  \
# 0           0.0     josephhoward@yahoo.com        400-108-5415
# 1           1.0     evansjeffery@yahoo.com      1-788-091-7546
# 2           2.0  andersonwilliam@yahoo.com        024.420.0375
# 3           3.0      rubenjuarez@yahoo.com  670.664.8168x94985
# 4           4.0           uchen@malone.com      1-981-877-0870
# ...

# %%
# filter for fraud emails
dfc_filtered = dfc2[dfc2['customer_email'].isin(['evansjeffery@yahoo.com', 'uchen@malone.com',
       'robinsoncynthia@dunn.com', 'samuel15@saunders-rhodes.com',
       'johnlowery@gmail.com', 'ubranch@rivera-parker.info',
       'bowenwilliam@yahoo.com', 'gonzalesjackson@gmail.com',
       'guerramichael@hotmail.com', 'catherine64@gmail.com',
       '9es7t@u6n7x', 'jamescampbell@randall-pacheco.biz',
       'kristina41@gmail.com', 'uguzman@yahoo.com',
       'feliciabrown@gmail.com', 'joserowland@jones.com',
       'hj8maoy@1jcfcxs7', 'suzanne21@gmail.com', 'cathy42@gibson.com',
       'nancymayo@brown.com', 'warrenedward@arnold.com',
       'michael57@oconnor.com', 'jonathan99@stafford.org',
       'lleonard@turner-fleming.com', 'whitedavid@jones-lloyd.org',
       'shelby24@hotmail.com', 'brittanydean@hotmail.com',
       'craig83@rasmussen-alvarado.com', 'ukline@spears.biz',
       'vmiller@hotmail.com', 'david45@gmail.com',
       'fdavis@wolfe-brown.com', 'mtrevino@gutierrez.net',
       'tmcpherson@wright.com', 'wdelacruz@yahoo.com',
       'brooksdustin@knight.info', '3fooiar@6eph', 'ugood@mosley.info',
       'marywalker@gmail.com', 'amywright@wallace-johnson.com',
       'iray@rogers.com', 'ctaylor@yahoo.com', 'koneal@henderson.biz',
       'oaguirre@hotmail.com', 'aliciaanthony@martin.com',
       'christinemills@mcgee.com', 'gwilcox@hotmail.com', '1yf0@jedyz63t',
       'kwalsh@lopez-gomez.biz', 'deborah38@yahoo.com',
       'andre74@patrick-decker.com', 'mitchellvickie@brewer-jones.com',
       'sbrown@hughes.biz', 'ethompson@jackson-sanders.com'])]
display(dfc_filtered)
# Out:
#      Unnamed: 0                     customer_email        customer_phone  \
# 1             1             evansjeffery@yahoo.com        1-788-091-7546
# 4             4                   uchen@malone.com        1-981-877-0870
# 5             5           robinsoncynthia@dunn.com      +65(5)8997489788
# 6             6       samuel15@saunders-rhodes.com           05045239487
# 7             7               johnlowery@gmail.com          044-642-9860
# 10           10             bowenwilliam@yahoo.com   (128)248-4091x37789
# 15           15          gonzalesjackson@gmail.com    1-410-373-1228x129
# 29           29              catherine64@gmail.com      563-396-2038x288
# 32           32                        9es7t@u6n7x      518.037.7423x366
# 45           45               johnlowery@gmail.com      +16(4)9016414340
# 46           46  jamescampbell@randall-pacheco.biz          599-142-6783
# 50           50               kristina41@gmail.com        1-836-334-7673
# ...

# %%
dfc_filtered.to_csv(r'C:\Users\pbevi\Documents\Week_5\Midproject-Ecommerce_fraud\dfc_filtered.csv')

# %%
dfc2e=dfc2['customer_email'].unique()
dfc2e
# Out:
# array(['josephhoward@yahoo.com', 'evansjeffery@yahoo.com',
#        'andersonwilliam@yahoo.com', 'rubenjuarez@yahoo.com',
#        'uchen@malone.com', 'robinsoncynthia@dunn.com',
#        'samuel15@saunders-rhodes.com', 'johnlowery@gmail.com',
#        'jameslandry@rodriguez.com', 'bowenwilliam@yahoo.com',
#        'ksummers@hotmail.com', 'christineklein@wright-boyd.org',
#        'meganwalters@chavez.com', 'caleb94@sutton.info',
#        'gonzalesjackson@gmail.com', 'dana09@yahoo.com', 'alec27@bell.com',
#        'juliecook@hotmail.com', 'meganberry@clark.biz',
#        'psantiago@nelson.net', 'harrisnicholas@mitchell-hancock.com',
#        'davismike@hotmail.com', 'natalie98@yahoo.com',
#        'karen54@mullins.biz', 'avaldez@gmail.com', 'blackjoel@wright.com',
#        'abigail08@yahoo.com', 'catherine64@gmail.com',
#        'romerolauren@hotmail.com', 'qramsey@hotmail.com', '9es7t@u6n7x',
#        'ypruitt@hotmail.com', 'aweaver@yahoo.com',
# ...

# %%
dfte=dft['customer_email'].unique()
dfte
# Out:
# array(['josephhoward@yahoo.com', 'evansjeffery@yahoo.com',
#        'andersonwilliam@yahoo.com', 'rubenjuarez@yahoo.com',
#        'uchen@malone.com', 'robinsoncynthia@dunn.com',
#        'samuel15@saunders-rhodes.com', 'johnlowery@gmail.com',
#        'jameslandry@rodriguez.com', 'bowenwilliam@yahoo.com',
#        'ksummers@hotmail.com', 'christineklein@wright-boyd.org',
#        'meganwalters@chavez.com', 'caleb94@sutton.info',
#        'gonzalesjackson@gmail.com', 'dana09@yahoo.com', 'alec27@bell.com',
#        'juliecook@hotmail.com', 'meganberry@clark.biz',
#        'psantiago@nelson.net', 'harrisnicholas@mitchell-hancock.com',
#        'davismike@hotmail.com', 'natalie98@yahoo.com',
#        'karen54@mullins.biz', 'avaldez@gmail.com', 'blackjoel@wright.com',
#        'abigail08@yahoo.com', 'catherine64@gmail.com',
#        'romerolauren@hotmail.com', 'qramsey@hotmail.com', '9es7t@u6n7x',
#        'ypruitt@hotmail.com', 'aweaver@yahoo.com',
# ...

# %%
def common(dfc2e,dfte): 
    dftotal = [value for value in dfc2e if value in dfte] 
    return dftotal
dftotal2=common(dfc2e,dfte)
print(dftotal2)
# Out:
# ['josephhoward@yahoo.com', 'evansjeffery@yahoo.com', 'andersonwilliam@yahoo.com', 'rubenjuarez@yahoo.com', 'uchen@malone.com', 'robinsoncynthia@dunn.com', 'samuel15@saunders-rhodes.com', 'johnlowery@gmail.com', 'jameslandry@rodriguez.com', 'bowenwilliam@yahoo.com', 'ksummers@hotmail.com', 'christineklein@wright-boyd.org', 'meganwalters@chavez.com', 'caleb94@sutton.info', 'gonzalesjackson@gmail.com', 'dana09@yahoo.com', 'alec27@bell.com', 'juliecook@hotmail.com', 'meganberry@clark.biz', 'psantiago@nelson.net', 'harrisnicholas@mitchell-hancock.com', 'davismike@hotmail.com', 'natalie98@yahoo.com', 'karen54@mullins.biz', 'avaldez@gmail.com', 'blackjoel@wright.com', 'abigail08@yahoo.com', 'catherine64@gmail.com', 'romerolauren@hotmail.com', 'qramsey@hotmail.com', '9es7t@u6n7x', 'ypruitt@hotmail.com', 'aweaver@yahoo.com', 'richard05@hanson-key.org', 'paul86@hotmail.com', 'mark02@young.com', 'brandon58@conner.com', 'jamescampbell@randall-pacheco.biz', 'briana34@gmail.com', 'jonesandrea@gray
# ...

# %%
#plotting the emails that got fraud

# %%
display(dft_filtered)
# Out:
#      Unnamed: 0                 customer_email transaction_id order_id  \
# 2             2         evansjeffery@yahoo.com       5mi94sfw   nlghpa
# 3             3         evansjeffery@yahoo.com       br8ba1nu   uw0eeb
# 4             4         evansjeffery@yahoo.com       a33145ss   bn44oh
# 13           13               uchen@malone.com       q8j3dgni   56h7iw
# 14           14               uchen@malone.com       xjulqy8x   kowj1v
# ..          ...                            ...            ...      ...
# 611         611  ethompson@jackson-sanders.com       piabwn96   cbxamb
# 612         612  ethompson@jackson-sanders.com       yneqvvwj   cbxamb
# 613         613  ethompson@jackson-sanders.com       l2t3xn9z   wjq6ep
# 614         614  ethompson@jackson-sanders.com       yb9ejssg   zynstd
# 615         615  ethompson@jackson-sanders.com       j3xzwavj   diw3zx
#
#     payment_method_id  payment_method_registration_failure  \
# ...

# %%
ax = dft_filtered['payment_method_provider'].value_counts().sort_index(ascending=False).plot(kind='barh',
                                    figsize=(8,5),
                                    title="Frequency Payment provider_fraud")
ax.set_xlabel("Frequency")
ax.set_ylabel("Providers")
plt.savefig('f_frequencyd.png')

# %%
payorder=['card','bitcoin','paypal','apple pay']
sns.countplot(x=dft_filtered.payment_method_type,
             order=payorder).set(title='payment type_fraud')
#order=payorder
plt.savefig('f_methodf.png')

# %%
sns.displot(data=dft_filtered, x="transaction_amount")
plt.savefig('f_transaction2.png')

# %%
sns.displot(data=dft_filtered, x="transaction_amount",hue="transaction_failed")
plt.savefig('f_transaction.png')

# %%
ax = dfc_filtered['state'].value_counts().plot(kind='barh',
                                    figsize=(7,5),
                                    title="States present in fraudulent customers")
plt.savefig('f_states.png')

# %%
sns.countplot(x=dft_filtered.order_state)
plt.savefig('f_order.png')

# %%
nonfraud = dfc2[dfc2['fraud'] == False]
display(nonfraud)
# Out:
#      Unnamed: 0             customer_email      customer_phone  \
# 0             0     josephhoward@yahoo.com        400-108-5415
# 2             2  andersonwilliam@yahoo.com        024.420.0375
# 3             3      rubenjuarez@yahoo.com  670.664.8168x94985
# 8             8  jameslandry@rodriguez.com  1-885-168-1310x338
# 11           11       ksummers@hotmail.com      1-023-275-4692
# ..          ...                        ...                 ...
# 157         157          daniel98@lamb.com  758.182.1357x89421
# 158         158        ujackson@harris.com    852-231-3642x738
# 159         159    brittanyhicks@jones.com    579-193-1785x676
# 162         162  patrickcalderon@russo.net    444-358-6570x947
# 167         167    dawn05@tucker-brown.com  (089)703-7360x8848
#
#           customer_device                      customer_ip_address  \
# 0    yyeiaxpltf82440jnb3v                             8.129.104.40
# 2    4m7h5ipl1shyavt6vv2r  67b7:3db8:67e0:3bea:b9d0:90c1:2b60:b9f0
# ...

# %%
#customer email with non fraud in customer df
nonfraud_e=nonfraud['customer_email'].unique()
nonfraud_e
# Out:
# array(['josephhoward@yahoo.com', 'andersonwilliam@yahoo.com',
#        'rubenjuarez@yahoo.com', 'jameslandry@rodriguez.com',
#        'ksummers@hotmail.com', 'christineklein@wright-boyd.org',
#        'meganwalters@chavez.com', 'caleb94@sutton.info',
#        'dana09@yahoo.com', 'alec27@bell.com', 'juliecook@hotmail.com',
#        'meganberry@clark.biz', 'psantiago@nelson.net',
#        'harrisnicholas@mitchell-hancock.com', 'davismike@hotmail.com',
#        'natalie98@yahoo.com', 'karen54@mullins.biz', 'avaldez@gmail.com',
#        'blackjoel@wright.com', 'abigail08@yahoo.com',
#        'romerolauren@hotmail.com', 'qramsey@hotmail.com',
#        'ypruitt@hotmail.com', 'aweaver@yahoo.com',
#        'richard05@hanson-key.org', 'paul86@hotmail.com',
#        'mark02@young.com', 'brandon58@conner.com', 'briana34@gmail.com',
#        'jonesandrea@gray.biz', 'nolanalec@yahoo.com',
#        'spencer77@reid.com', 'ssmith@levine-harmon.biz',
# ...

# %%
# filter for non fraud emails
dft_filtered_nf = dft[dft['customer_email'].isin(['josephhoward@yahoo.com', 'andersonwilliam@yahoo.com',
       'rubenjuarez@yahoo.com', 'jameslandry@rodriguez.com',
       'ksummers@hotmail.com', 'christineklein@wright-boyd.org',
       'meganwalters@chavez.com', 'caleb94@sutton.info',
       'dana09@yahoo.com', 'alec27@bell.com', 'juliecook@hotmail.com',
       'meganberry@clark.biz', 'psantiago@nelson.net',
       'harrisnicholas@mitchell-hancock.com', 'davismike@hotmail.com',
       'natalie98@yahoo.com', 'karen54@mullins.biz', 'avaldez@gmail.com',
       'blackjoel@wright.com', 'abigail08@yahoo.com',
       'romerolauren@hotmail.com', 'qramsey@hotmail.com',
       'ypruitt@hotmail.com', 'aweaver@yahoo.com',
       'richard05@hanson-key.org', 'paul86@hotmail.com',
       'mark02@young.com', 'brandon58@conner.com', 'briana34@gmail.com',
       'jonesandrea@gray.biz', 'nolanalec@yahoo.com',
       'spencer77@reid.com', 'ssmith@levine-harmon.biz',
       'dianacook@gmail.com', 'cookbenjamin@hotmail.com',
       'pattersonphilip@yahoo.com', 'finleybrianna@yahoo.com',
       'kristaavery@lewis-baird.com', 'michelleherrera@day.info',
       'ijuarez@yahoo.com', 'hughesjonathan@pena.org',
       'anthony04@gmail.com', 'mgould@yahoo.com', 'bakersydney@gmail.com',
       'udavis@clark.com', 'rbolton@hotmail.com', 'tayloreric@gmail.com',
       'cindydelgado@gmail.com', 'watkinscaroline@lewis-haas.com',
       'marissacollins@mckinney.com', 'thernandez@johnson-quinn.com',
       'emilyroberts@hotmail.com', 'kathleenlee@yahoo.com',
       'benjamin19@gmail.com', 'ybrown@gmail.com', 'vreyes@cruz.info',
       'nicolekelly@hotmail.com', 'barronelizabeth@singh.org',
       'phillip89@gmail.com', 'zgraham@yahoo.com', 'pchavez@randolph.com',
       'smithtonya@huffman.org', 'hamiltonchristopher@yahoo.com',
       'gomezjohn@yahoo.com', 'mullenstephanie@yahoo.com',
       'brianthomas@yahoo.com', 'joshua00@hotmail.com',
       'veronica42@stokes.com', 'cindydeleon@yahoo.com',
       'kyle64@stephens-ortiz.com', 'jordanthomas@hayes-wilson.biz',
       'jenniferperry@hotmail.com', 'lsanchez@hotmail.com',
       'cuevasvicki@gmail.com', 'mitchellgriffith@yahoo.com',
       'victorgarcia@gmail.com', 'brittany60@yahoo.com',
       'fharris@hotmail.com', 'mercedesfinley@roman.org',
       'thomasryan@conrad.net', 'martinezlori@gmail.com',
       'stevehernandez@gmail.com', 'daniel98@lamb.com',
       'ujackson@harris.com', 'brittanyhicks@jones.com',
       'patrickcalderon@russo.net', 'dawn05@tucker-brown.com'])]
display(dft_filtered_nf)
# Out:
#      Unnamed: 0             customer_email transaction_id order_id  \
# 0             0     josephhoward@yahoo.com       a9lcj51r   vjbdvd
# 1             1     josephhoward@yahoo.com       y4wcv03i   yp6x27
# 5             5  andersonwilliam@yahoo.com       q3lyvbza   yk34y2
# 6             6  andersonwilliam@yahoo.com       3alf9irw   28v6b0
# 7             7  andersonwilliam@yahoo.com       69w9wymx   28v6b0
# ..          ...                        ...            ...      ...
# 618         618    dawn05@tucker-brown.com       7yilsi1o   1bubxa
# 619         619    dawn05@tucker-brown.com       c82k5bcv   1bubxa
# 620         620    dawn05@tucker-brown.com       wmh52bns   1bubxa
# 621         621    dawn05@tucker-brown.com       xdw33hfp   p0gdbf
# 622         622    dawn05@tucker-brown.com       wgmajf82   5lmvrj
#
#     payment_method_id  payment_method_registration_failure  \
# 0           wt07xm68b                                    1
# ...

# %%
dft_filtered_nf.to_csv(r'C:\Users\pbevi\Documents\Week_5\Midproject-Ecommerce_fraud\dft_filtered_nf.csv')

# %%
dfc_filtered_nf = dfc2[dfc2['customer_email'].isin(['josephhoward@yahoo.com', 'andersonwilliam@yahoo.com',
       'rubenjuarez@yahoo.com', 'jameslandry@rodriguez.com',
       'ksummers@hotmail.com', 'christineklein@wright-boyd.org',
       'meganwalters@chavez.com', 'caleb94@sutton.info',
       'dana09@yahoo.com', 'alec27@bell.com', 'juliecook@hotmail.com',
       'meganberry@clark.biz', 'psantiago@nelson.net',
       'harrisnicholas@mitchell-hancock.com', 'davismike@hotmail.com',
       'natalie98@yahoo.com', 'karen54@mullins.biz', 'avaldez@gmail.com',
       'blackjoel@wright.com', 'abigail08@yahoo.com',
       'romerolauren@hotmail.com', 'qramsey@hotmail.com',
       'ypruitt@hotmail.com', 'aweaver@yahoo.com',
       'richard05@hanson-key.org', 'paul86@hotmail.com',
       'mark02@young.com', 'brandon58@conner.com', 'briana34@gmail.com',
       'jonesandrea@gray.biz', 'nolanalec@yahoo.com',
       'spencer77@reid.com', 'ssmith@levine-harmon.biz',
       'dianacook@gmail.com', 'cookbenjamin@hotmail.com',
       'pattersonphilip@yahoo.com', 'finleybrianna@yahoo.com',
       'kristaavery@lewis-baird.com', 'michelleherrera@day.info',
       'ijuarez@yahoo.com', 'hughesjonathan@pena.org',
       'anthony04@gmail.com', 'mgould@yahoo.com', 'bakersydney@gmail.com',
       'udavis@clark.com', 'rbolton@hotmail.com', 'tayloreric@gmail.com',
       'cindydelgado@gmail.com', 'watkinscaroline@lewis-haas.com',
       'marissacollins@mckinney.com', 'thernandez@johnson-quinn.com',
       'emilyroberts@hotmail.com', 'kathleenlee@yahoo.com',
       'benjamin19@gmail.com', 'ybrown@gmail.com', 'vreyes@cruz.info',
       'nicolekelly@hotmail.com', 'barronelizabeth@singh.org',
       'phillip89@gmail.com', 'zgraham@yahoo.com', 'pchavez@randolph.com',
       'smithtonya@huffman.org', 'hamiltonchristopher@yahoo.com',
       'gomezjohn@yahoo.com', 'mullenstephanie@yahoo.com',
       'brianthomas@yahoo.com', 'joshua00@hotmail.com',
       'veronica42@stokes.com', 'cindydeleon@yahoo.com',
       'kyle64@stephens-ortiz.com', 'jordanthomas@hayes-wilson.biz',
       'jenniferperry@hotmail.com', 'lsanchez@hotmail.com',
       'cuevasvicki@gmail.com', 'mitchellgriffith@yahoo.com',
       'victorgarcia@gmail.com', 'brittany60@yahoo.com',
       'fharris@hotmail.com', 'mercedesfinley@roman.org',
       'thomasryan@conrad.net', 'martinezlori@gmail.com',
       'stevehernandez@gmail.com', 'daniel98@lamb.com',
       'ujackson@harris.com', 'brittanyhicks@jones.com',
       'patrickcalderon@russo.net', 'dawn05@tucker-brown.com'])]
display(dfc_filtered_nf)
# Out:
#      Unnamed: 0             customer_email      customer_phone  \
# 0             0     josephhoward@yahoo.com        400-108-5415
# 2             2  andersonwilliam@yahoo.com        024.420.0375
# 3             3      rubenjuarez@yahoo.com  670.664.8168x94985
# 8             8  jameslandry@rodriguez.com  1-885-168-1310x338
# 11           11       ksummers@hotmail.com      1-023-275-4692
# ..          ...                        ...                 ...
# 157         157          daniel98@lamb.com  758.182.1357x89421
# 158         158        ujackson@harris.com    852-231-3642x738
# 159         159    brittanyhicks@jones.com    579-193-1785x676
# 162         162  patrickcalderon@russo.net    444-358-6570x947
# 167         167    dawn05@tucker-brown.com  (089)703-7360x8848
#
#           customer_device                      customer_ip_address  \
# 0    yyeiaxpltf82440jnb3v                             8.129.104.40
# 2    4m7h5ipl1shyavt6vv2r  67b7:3db8:67e0:3bea:b9d0:90c1:2b60:b9f0
# ...

# %%
dfc_filtered_nf.to_csv(r'C:\Users\pbevi\Documents\Week_5\Midproject-Ecommerce_fraud\dfc_filtered_nf.csv')

# %%
#plotting for non fraud customer behavior

# %%
pporder=['Mastercard','Discover','VISA 13 digit','American Express','Voyager','JCB 15 digit', 'Diners Club/ Carte Blanche', 'VISA 16 digit', 'Maestro', 'JCB 16']
ax = dft_filtered_nf['payment_method_provider'].value_counts().sort_index(ascending=False).plot(kind='barh',
                                                         
                                    title="Frequency Payment provider")
ax.set_xlabel("Frequency")
ax.set_ylabel("Providers")
order=pporder
plt.savefig('nf_freq.png')

# %%
payorder=['card','bitcoin','paypal','apple pay']
sns.countplot(x=dft_filtered_nf.payment_method_type,order=payorder).set(title='payment type')

plt.savefig('f_method.png')

# %%
payorder=['card','bitcoin','paypal','apple pay']
sns.countplot(x=dft_filtered_nf.payment_method_type).set(title='payment type')
order=payorder

# %%
sns.displot(data=dft_filtered_nf, x="transaction_amount")
plt.savefig('nf_transactionamount.png')

# %%
    color = ["blue","orange","green","red"])

# %%
sns.displot(data=dft_filtered_nf, x="transaction_amount",hue="transaction_failed")
plt.savefig('nf_transactionfailed.png')

# %%
ax = dfc_filtered_nf['state'].value_counts().plot(kind='barh',
                                    figsize=(7,5),
                                    title="States")
plt.savefig('states_nf')

# %%
pd.crosstab(dft.payment_method_provider, dft.order_state)

# %%
sns.displot(data=dft, y="payment_method_provider", hue="order_state", multiple="stack");
plt.savefig('stack')

# %%
display(dfc_filtered)
# Out:
#      Unnamed: 0                     customer_email        customer_phone  \
# 1             1             evansjeffery@yahoo.com        1-788-091-7546
# 4             4                   uchen@malone.com        1-981-877-0870
# 5             5           robinsoncynthia@dunn.com      +65(5)8997489788
# 6             6       samuel15@saunders-rhodes.com           05045239487
# 7             7               johnlowery@gmail.com          044-642-9860
# 10           10             bowenwilliam@yahoo.com   (128)248-4091x37789
# 15           15          gonzalesjackson@gmail.com    1-410-373-1228x129
# 29           29              catherine64@gmail.com      563-396-2038x288
# 32           32                        9es7t@u6n7x      518.037.7423x366
# 45           45               johnlowery@gmail.com      +16(4)9016414340
# 46           46  jamescampbell@randall-pacheco.biz          599-142-6783
# 50           50               kristina41@gmail.com        1-836-334-7673
# ...

# %%
display(dft_filtered)
# Out:
#      Unnamed: 0                 customer_email transaction_id order_id  \
# 2             2         evansjeffery@yahoo.com       5mi94sfw   nlghpa
# 3             3         evansjeffery@yahoo.com       br8ba1nu   uw0eeb
# 4             4         evansjeffery@yahoo.com       a33145ss   bn44oh
# 13           13               uchen@malone.com       q8j3dgni   56h7iw
# 14           14               uchen@malone.com       xjulqy8x   kowj1v
# ..          ...                            ...            ...      ...
# 611         611  ethompson@jackson-sanders.com       piabwn96   cbxamb
# 612         612  ethompson@jackson-sanders.com       yneqvvwj   cbxamb
# 613         613  ethompson@jackson-sanders.com       l2t3xn9z   wjq6ep
# 614         614  ethompson@jackson-sanders.com       yb9ejssg   zynstd
# 615         615  ethompson@jackson-sanders.com       j3xzwavj   diw3zx
#
#     payment_method_id  payment_method_registration_failure  \
# ...

# %%
sns.displot(data=dft_filtered, x="transaction_amount",hue="payment_method_provider")
plt.savefig('persona1.png')

# %%
sns.displot(data=dft_filtered, y="transaction_amount", hue="payment_method_provider", multiple="stack");
plt.savefig('stack')

# %%
sns.displot(data=dft_filtered, x="customer_email")
plt.savefig('nf_transactionamount.png')

# %%
ax = dfc_filtered['customer_email'].value_counts().plot(kind='barh',
                                    figsize=(10,7),
                                    title="N.Orders")
plt.savefig('persona2')

# %% [raw]
# sns.displot(data=dfc_filtered, x="no_orders",hue="fraud")
# plt.savefig('persona4d.png')

# %%
pd.crosstab(dfc_filtered.customer_email, dfc_filtered.no_orders)
# Out:
# no_orders                          1  2  3  4  5  6  7  8
# customer_email
# 1yf0@jedyz63t                      0  0  0  0  1  0  0  0
# 9es7t@u6n7x                        1  0  0  0  0  0  0  0
# aliciaanthony@martin.com           0  0  1  0  0  0  0  0
# amywright@wallace-johnson.com      0  0  0  0  0  1  0  0
# andre74@patrick-decker.com         0  0  0  1  0  0  0  0
# bowenwilliam@yahoo.com             0  0  0  0  1  0  0  0
# brittanydean@hotmail.com           0  0  0  1  0  0  0  0
# brooksdustin@knight.info           1  0  0  0  0  0  0  0
# catherine64@gmail.com              0  0  0  1  0  0  0  0
# cathy42@gibson.com                 0  0  1  0  0  0  0  0
# christinemills@mcgee.com           0  0  0  0  1  0  0  0
# craig83@rasmussen-alvarado.com     0  1  0  0  0  0  0  0
# ctaylor@yahoo.com                  0  0  0  0  0  1  0  0
# david45@gmail.com                  0  0  0  0  0  0  0  1
# deborah38@yahoo.com                1  0  0  0  0  0  0  0
# ...

# %%
#payorder=['card','bitcoin','paypal','apple pay']
sns.countplot(x=dfc_filtered.no_orders).set(title='no_orders')
plt.savefig('persona5.png')

# %%
sns.displot(data=dtotal, x="no_orders",hue="transaction_failed")
plt.savefig('persona6.png')

# %%
sns.displot(dft_filtered, x="customer_email",hue="transaction_failed")
plt.savefig('persona7.png')

# %%
sns.displot(data=dft_filtered, y="customer_email", hue="transaction_failed", multiple="stack");
plt.savefig('persona8')
